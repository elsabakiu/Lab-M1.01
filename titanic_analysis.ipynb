# %%
"""
Titanic Data Analysis and JSON Export
Author: Elsa Bakiu
Description: Analyze Titanic passenger data, engineer features, and export to JSON
"""

import pandas as pd
import numpy as np
import json
from pathlib import Path

# Set up paths
DATA_DIR = Path("data")
CSV_FILE = DATA_DIR / "titanic.csv"
JSON_FILE = DATA_DIR / "titanic_data.json"

# Create data directory if it doesn't exist
DATA_DIR.mkdir(exist_ok=True)

print("Project setup complete!")
print(f"Data directory: {DATA_DIR}")
print(f"CSV file location: {CSV_FILE}")
# Out:
# Project setup complete!
# Data directory: data
# CSV file location: data/titanic.csv

# %%
df = pd.read_csv(CSV_FILE)
print(f"Dataset loaded successfully! Shape: {df.shape}")
print(f"\nColumns: {list(df.columns)}")
print(f"\nFirst few rows:")
print(df.head())
# Out:
# Dataset loaded successfully! Shape: (891, 12)
#
# Columns: ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']
#
# First few rows:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df = pd.read_csv(CSV_FILE)
# Select numeric columns only
numeric_df = df.select_dtypes(include="number")
# Calculate statistics for each numeric column
stats = numeric_df.agg(["mean", "median", "std"])
# Print the transposed statistics for better readability
stats_t = stats.T
print(stats_t)
# Out:
#                    mean    median         std
# PassengerId  446.000000  446.0000  257.353842
# Survived       0.383838    0.0000    0.486592
# Pclass         2.308642    3.0000    0.836071
# Age           29.699118   28.0000   14.526497
# SibSp          0.523008    0.0000    1.102743
# Parch          0.381594    0.0000    0.806057
# Fare          32.204208   14.4542   49.693429

# %%
df = pd.read_csv(CSV_FILE)
# Count missing values
print("\n" + "="*50)
print("MISSING VALUES ANALYSIS")
print("="*50)
 
missing_data = {}
 
for col in df.columns:
    missing_count = df[col].isna().sum()
    missing_percent = (missing_count / len(df)) * 100

    missing_data[col] = {
        "missing_count": missing_count,
        "missing_percent": round(missing_percent, 2)
    }

# Print missing data summary
for col, stats in missing_data.items():
    print(f"{col}: {stats['missing_count']} missing values ({stats['missing_percent']}%)")
# Out:
# ==================================================
# MISSING VALUES ANALYSIS
# ==================================================
# PassengerId: 0 missing values (0.0%)
# Survived: 0 missing values (0.0%)
# Pclass: 0 missing values (0.0%)
# Name: 0 missing values (0.0%)
# Sex: 0 missing values (0.0%)
# Age: 177 missing values (19.87%)
# SibSp: 0 missing values (0.0%)
# Parch: 0 missing values (0.0%)
# Ticket: 0 missing values (0.0%)
# Fare: 0 missing values (0.0%)
# Cabin: 687 missing values (77.1%)
# Embarked: 2 missing values (0.22%)

# %%
# Create a copy of the dataframe for feature engineering
df_features = df.copy()
 
# Feature 1: Family Size
df_features['FamilySize'] = df_features['FamilySize'] = df_features['SibSp'] + df_features['Parch'] + 1
print(df_features[['SibSp', 'Parch', 'FamilySize']].head(10))
 
# Feature 2: Is Alone
df_features['IsAlone'] = df_features['IsAlone'] = (df_features['FamilySize'] == 1).astype(int)
print(df_features[['FamilySize', 'IsAlone']].head(10))
 
# Feature 3: Age Groups
def categorize_age(age):
    """Categorize age into groups"""
    if pd.isna(age):
        return 'Unknown'
    elif age < 18:
        return 'name your category'
    elif age < 30:
        return 'name your category'
    elif age < 50:
        return 'name your category'
    else:
        return 'name your category'
 
df_features['AgeGroup'] = df_features['AgeGroup'] = df_features['Age'].apply(categorize_age)
print(df_features[['Age', 'AgeGroup']].head(10))
 
# Analyze feature differences between survivors and non-survivors
print("\n" + "="*50)
print("FEATURE ANALYSIS: SURVIVED vs NOT SURVIVED")
print("="*50)
 
# Here is an example to get you started:
print("\nFamily Size by Survival:")
family_survival = df_features.groupby('Survived')['FamilySize'].agg(['mean', 'median', 'std'])
print(family_survival)
 
# Statistical test: Do these features help differentiate?
print("\n" + "="*50)
print("FEATURE DIFFERENTIATION ANALYSIS")
print("="*50)
 
survived = df_features[df_features['Survived'] == 1]
not_survived = df_features[df_features['Survived'] == 0]
 
print("\nFamily Size:")
print(f"  Survived mean: {survived['FamilySize'].mean():.2f}")
print(f"  Not Survived mean: {not_survived['FamilySize'].mean():.2f}")
print(f"  Difference: {abs(survived['FamilySize'].mean() - not_survived['FamilySize'].mean()):.2f}")
# Out:
#    SibSp  Parch  FamilySize
# 0      1      0           2
# 1      1      0           2
# 2      0      0           1
# 3      1      0           2
# 4      0      0           1
# 5      0      0           1
# 6      0      0           1
# 7      3      1           5
# 8      0      2           3
# 9      1      0           2
#    FamilySize  IsAlone
# 0           2        0
# 1           2        0
# 2           1        1
# 3           2        0
# 4           1        1
# 5           1        1
# 6           1        1
# 7           5        0
# 8           3        0
# 9           2        0
#     Age            AgeGroup
# 0  22.0  name your category
# 1  38.0  name your category
# 2  26.0  name your category
# 3  35.0  name your category
# 4  35.0  name your category
# 5   NaN             Unknown
# 6  54.0  name your category
# 7   2.0  name your category
# 8  27.0  name your category
# 9  14.0  name your category
#
# ==================================================
# FEATURE ANALYSIS: SURVIVED vs NOT SURVIVED
# ==================================================
#
# Family Size by Survival:
#               mean  median       std
# Survived
# 0         1.883424     1.0  1.830669
# 1         1.938596     2.0  1.186076
#
# ==================================================
# FEATURE DIFFERENTIATION ANALYSIS
# ==================================================
#
# Family Size:
#   Survived mean: 1.94
#   Not Survived mean: 1.88
#   Difference: 0.06

# %%
import json
from datetime import datetime

import pandas as pd


# -----------------------------
# 1) Load CSV into df
# -----------------------------
df = pd.read_csv(CSV_FILE)


# -----------------------------
# 2) Create df_engineered
#    - FamilySize = SibSp + Parch + 1
#    - IsAlone = 1 if FamilySize == 1 else 0
#    - Title extracted from Name
# -----------------------------
df_engineered = df.copy()

# FamilySize
df_engineered["FamilySize"] = (
    df_engineered["SibSp"].fillna(0).astype(int)
    + df_engineered["Parch"].fillna(0).astype(int)
    + 1
)

# IsAlone
df_engineered["IsAlone"] = (df_engineered["FamilySize"] == 1).astype(int)


def extract_title(name):
    if not isinstance(name, str) or "," not in name or "." not in name:
        return None
    try:
        return name.split(",")[1].split(".")[0].strip()
    except Exception:
        return None


df_engineered["Title"] = df_engineered["Name"].apply(extract_title)


# -----------------------------
# 3) Passenger + TitanicDataset classes
# -----------------------------
class Passenger:
    """
    Represents a passenger with all their information.
    """

    def __init__(
        self,
        passenger_id,
        name,
        age,
        sex,
        survived,
        pclass,
        fare,
        embarked=None,
        sibsp=None,
        parch=None,
        family_size=None,
        is_alone=None,
        title=None,
    ):
        # Core identifiers
        self.passenger_id = int(passenger_id) if pd.notna(passenger_id) else None
        self.name = str(name) if pd.notna(name) else None

        # Survival and class
        self.survived = int(survived) if pd.notna(survived) else None
        self.pclass = int(pclass) if pd.notna(pclass) else None

        # Demographics
        self.age = float(age) if pd.notna(age) else None
        self.sex = str(sex) if pd.notna(sex) else None

        # Ticket / travel
        self.fare = float(fare) if pd.notna(fare) else None
        self.embarked = str(embarked) if pd.notna(embarked) else None

        # Family components
        self.sibsp = int(sibsp) if pd.notna(sibsp) else None
        self.parch = int(parch) if pd.notna(parch) else None

        # Engineered features
        self.family_size = int(family_size) if pd.notna(family_size) else None
        self.is_alone = int(is_alone) if pd.notna(is_alone) else None
        self.title = str(title) if pd.notna(title) else None

    def to_dict(self):
        """Convert passenger to dictionary for JSON serialization."""
        return {
            "passenger_id": self.passenger_id,
            "name": self.name,
            "age": self.age,
            "sex": self.sex,
            "survived": self.survived,
            "pclass": self.pclass,
            "fare": self.fare,
            "embarked": self.embarked,
            "sibsp": self.sibsp,
            "parch": self.parch,
            "family_size": self.family_size,
            "is_alone": self.is_alone,
            "title": self.title,
        }


class TitanicDataset:
    """
    Represents the entire Titanic dataset with methods for analysis and JSON export.
    """

    def __init__(self, dataframe: pd.DataFrame):
        if dataframe is None or dataframe.empty:
            raise ValueError("TitanicDataset requires a non-empty DataFrame.")

        self.dataframe = dataframe.copy()
        self.passengers = []
        self._create_passengers()

    def _create_passengers(self):
        """Create Passenger objects from dataframe."""
        self.passengers = []
        for idx, row in self.dataframe.iterrows():
            passenger = Passenger(
                passenger_id=row.get("PassengerId", idx),
                name=row.get("Name", None),
                age=row.get("Age", None),
                sex=row.get("Sex", None),
                survived=row.get("Survived", None),
                pclass=row.get("Pclass", None),
                fare=row.get("Fare", None),
                embarked=row.get("Embarked", None),
                sibsp=row.get("SibSp", None),
                parch=row.get("Parch", None),
                family_size=row.get("FamilySize", None),
                is_alone=row.get("IsAlone", None),
                title=row.get("Title", None),
            )
            self.passengers.append(passenger)

    # ---------- Missing values ----------

    def get_missing_values_summary(self):
        """
        Returns:
        { "ColumnName": {"missing_count": int, "missing_percent": float}, ... }
        """
        df = self.dataframe
        missing_count = df.isna().sum()
        missing_percent = (df.isna().mean() * 100).round(2)

        summary = {}
        for col in df.columns:
            summary[col] = {
                "missing_count": int(missing_count[col]),
                "missing_percent": float(missing_percent[col]),
            }
        return summary

    def get_columns_with_most_missing(self, top_n=10):
        """
        Returns list sorted by missing_percent descending:
        [(col, missing_count, missing_percent), ...]
        """
        summary = self.get_missing_values_summary()
        ranked = sorted(
            [(c, v["missing_count"], v["missing_percent"]) for c, v in summary.items()],
            key=lambda x: x[2],
            reverse=True,
        )
        return ranked[:top_n]

    # ---------- Numeric stats ----------

    def get_numeric_stats(self, round_to=3):
        """
        mean, median, std for each numeric column.
        Returns:
        { "colA": {"mean": .., "median": .., "std": ..}, ... }
        """
        num_df = self.dataframe.select_dtypes(include="number")
        if num_df.empty:
            return {}

        stats = num_df.agg(["mean", "median", "std"]).T.round(round_to)

        out = {}
        for col in stats.index:
            out[col] = {
                "mean": None if pd.isna(stats.loc[col, "mean"]) else float(stats.loc[col, "mean"]),
                "median": None if pd.isna(stats.loc[col, "median"]) else float(stats.loc[col, "median"]),
                "std": None if pd.isna(stats.loc[col, "std"]) else float(stats.loc[col, "std"]),
            }
        return out

    # ---------- Summary stats ----------

    def get_summary_stats(self):
        total_passengers = len(self.passengers)

        survived_count = sum(1 for p in self.passengers if p.survived == 1)
        did_not_survive = sum(1 for p in self.passengers if p.survived == 0)

        ages = [p.age for p in self.passengers if p.age is not None]
        fares = [p.fare for p in self.passengers if p.fare is not None]
        family_sizes = [p.family_size for p in self.passengers if p.family_size is not None]

        average_age = round(sum(ages) / len(ages), 3) if ages else None
        average_fare = round(sum(fares) / len(fares), 3) if fares else None
        average_family_size = round(sum(family_sizes) / len(family_sizes), 3) if family_sizes else None

        survival_rate = None
        if "Survived" in self.dataframe.columns and not self.dataframe["Survived"].isna().all():
            survival_rate = float(self.dataframe["Survived"].mean())

        return {
            "total_passengers": total_passengers,
            "survived": survived_count,
            "did_not_survive": did_not_survive,
            "survival_rate": survival_rate,
            "average_age": average_age,
            "average_fare": average_fare,
            "average_family_size": average_family_size,
        }

    # ---------- JSON export ----------

    def to_json(self, filename="titanic_data.json", indent=2):
        data = {
            "metadata": {
                "dataset_name": "Titanic Passenger Dataset",
                "export_date": datetime.now().isoformat(),
                "rows": int(self.dataframe.shape[0]),
                "columns": int(self.dataframe.shape[1]),
                "column_names": list(self.dataframe.columns),
                "summary_stats": self.get_summary_stats(),
                "missing_values": self.get_missing_values_summary(),
                "top_missing_columns": [
                    {"column": c, "missing_count": mc, "missing_percent": mp}
                    for (c, mc, mp) in self.get_columns_with_most_missing(top_n=10)
                ],
                "numeric_column_stats": self.get_numeric_stats(round_to=3),
                "engineered_features": {
                    "FamilySize": "SibSp + Parch + 1",
                    "IsAlone": "1 if FamilySize == 1 else 0",
                    "Title": "Extracted from Name (text between ',' and '.')",
                },
            },
            "passengers": [p.to_dict() for p in self.passengers],
        }

        with open(filename, "w", encoding="utf-8") as f:
            json.dump(data, f, indent=indent, ensure_ascii=False)

        print(f"Data exported to {filename}")
        return data


# -----------------------------
# 4) Create dataset, print stats, optional JSON export
# -----------------------------
dataset = TitanicDataset(df_engineered)

print("\n" + "=" * 50)
print("BASIC DATASET INFO")
print("=" * 50)
print("Rows:", dataset.dataframe.shape[0])
print("Columns:", dataset.dataframe.shape[1])

print("\n" + "=" * 50)
print("SUMMARY STATS")
print("=" * 50)
summary = dataset.get_summary_stats()
for k, v in summary.items():
    print(f"{k}: {v}")

print("\n" + "=" * 50)
print("TOP MISSING COLUMNS")
print("=" * 50)
for col, mc, mp in dataset.get_columns_with_most_missing(top_n=10):
    if mc > 0:
        print(f"{col}: {mc} missing ({mp}%)")

#Export to JSON
dataset.to_json(JSON_FILE)
# Out:
# ==================================================
# BASIC DATASET INFO
# ==================================================
# Rows: 891
# Columns: 15
#
# ==================================================
# SUMMARY STATS
# ==================================================
# total_passengers: 891
# survived: 342
# did_not_survive: 549
# survival_rate: 0.3838383838383838
# average_age: 29.699
# average_fare: 32.204
# average_family_size: 1.905
#
# ==================================================
# TOP MISSING COLUMNS
# ==================================================
# Cabin: 687 missing (77.1%)
# Age: 177 missing (19.87%)
# Embarked: 2 missing (0.22%)
# Data exported to data/titanic_data.json
# {'metadata': {'dataset_name': 'Titanic Passenger Dataset',
#   'export_date': '2026-02-03T18:09:39.010376',
#   'rows': 891,
#   'columns': 15,
#   'column_names': ['PassengerId',
#    'Survived',
#    'Pclass',
#    'Name',
#    'Sex',
#    'Age',
#    'SibSp',
#    'Parch',
#    'Ticket',
#    'Fare',
#    'Cabin',
#    'Embarked',
#    'FamilySize',
#    'IsAlone',
#    'Title'],
#   'summary_stats': {'total_passengers': 891,
#    'survived': 342,
#    'did_not_survive': 549,
#    'survival_rate': 0.3838383838383838,
#    'average_age': 29.699,
#    'average_fare': 32.204,
#    'average_family_size': 1.905},
#   'missing_values': {'PassengerId': {'missing_count': 0,
#     'missing_percent': 0.0},
#    'Survived': {'missing_count': 0, 'missing_percent': 0.0},
#    'Pclass': {'missing_count': 0, 'missing_percent': 0.0},
#    'Name': {'missing_count': 0, 'missing_percent': 0.0},
#    'Sex': {'missing_count': 0, 'missing_percent': 0.0},
#    'Age': {'missing_count': 177, 'missing_percent': 19.87},
#    'SibSp': {'missing_count': 0, 'missing_percent': 0.0},
#    'Parch': {'missing_count': 0, 'missing_percent': 0.0},
#    'Ticket': {'missing_count': 0, 'missing_percent': 0.0},
#    'Fare': {'missing_count': 0, 'missing_percent': 0.0},
#    'Cabin': {'missing_count': 687, 'missing_percent': 77.1},
#    'Embarked': {'missing_count': 2, 'missing_percent': 0.22},
#    'FamilySize': {'missing_count': 0, 'missing_percent': 0.0},
#    'IsAlone': {'missing_count': 0, 'missing_percent': 0.0},
#    'Title': {'missing_count': 0, 'missing_percent': 0.0}},
#   'top_missing_columns': [{'column': 'Cabin',
#     'missing_count': 687,
#     'missing_percent': 77.1},
#    {'column': 'Age', 'missing_count': 177, 'missing_percent': 19.87},
#    {'column': 'Embarked', 'missing_count': 2, 'missing_percent': 0.22},
#    {'column': 'PassengerId', 'missing_count': 0, 'missing_percent': 0.0},
#    {'column': 'Survived', 'missing_count': 0, 'missing_percent': 0.0},
#    {'column': 'Pclass', 'missing_count': 0, 'missing_percent': 0.0},
#    {'column': 'Name', 'missing_count': 0, 'missing_percent': 0.0},
#    {'column': 'Sex', 'missing_count': 0, 'missing_percent': 0.0},
#    {'column': 'SibSp', 'missing_count': 0, 'missing_percent': 0.0},
#    {'column': 'Parch', 'missing_count': 0, 'missing_percent': 0.0}],
#   'numeric_column_stats': {'PassengerId': {'mean': 446.0,
#     'median': 446.0,
#     'std': 257.354},
#    'Survived': {'mean': 0.384, 'median': 0.0, 'std': 0.487},
#    'Pclass': {'mean': 2.309, 'median': 3.0, 'std': 0.836},
#    'Age': {'mean': 29.699, 'median': 28.0, 'std': 14.526},
#    'SibSp': {'mean': 0.523, 'median': 0.0, 'std': 1.103},
#    'Parch': {'mean': 0.382, 'median': 0.0, 'std': 0.806},
#    'Fare': {'mean': 32.204, 'median': 14.454, 'std': 49.693},
#    'FamilySize': {'mean': 1.905, 'median': 1.0, 'std': 1.613},
#    'IsAlone': {'mean': 0.603, 'median': 1.0, 'std': 0.49}},
#   'engineered_features': {'FamilySize': 'SibSp + Parch + 1',
#    'IsAlone': '1 if FamilySize == 1 else 0',
#    'Title': "Extracted from Name (text between ',' and '.')"}},
#  'passengers': [{'passenger_id': 1,
#    'name': 'Braund, Mr. Owen Harris',
#    'age': 22.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 7.25,
#    'embarked': 'S',
#    'sibsp': 1,
#    'parch': 0,
#    'family_size': 2,
#    'is_alone': 0,
#    'title': 'Mr'},
#   {'passenger_id': 2,
#    'name': 'Cumings, Mrs. John Bradley (Florence Briggs Thayer)',
#    'age': 38.0,
#    'sex': 'female',
#    'survived': 1,
#    'pclass': 1,
#    'fare': 71.2833,
#    'embarked': 'C',
#    'sibsp': 1,
#    'parch': 0,
#    'family_size': 2,
#    'is_alone': 0,
#    'title': 'Mrs'},
#   {'passenger_id': 3,
#    'name': 'Heikkinen, Miss. Laina',
#    'age': 26.0,
#    'sex': 'female',
#    'survived': 1,
#    'pclass': 3,
#    'fare': 7.925,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Miss'},
#   {'passenger_id': 4,
#    'name': 'Futrelle, Mrs. Jacques Heath (Lily May Peel)',
#    'age': 35.0,
#    'sex': 'female',
#    'survived': 1,
#    'pclass': 1,
#    'fare': 53.1,
#    'embarked': 'S',
#    'sibsp': 1,
#    'parch': 0,
#    'family_size': 2,
#    'is_alone': 0,
#    'title': 'Mrs'},
#   {'passenger_id': 5,
#    'name': 'Allen, Mr. William Henry',
#    'age': 35.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 8.05,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 6,
#    'name': 'Moran, Mr. James',
#    'age': None,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 8.4583,
#    'embarked': 'Q',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 7,
#    'name': 'McCarthy, Mr. Timothy J',
#    'age': 54.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 1,
#    'fare': 51.8625,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 8,
#    'name': 'Palsson, Master. Gosta Leonard',
#    'age': 2.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 21.075,
#    'embarked': 'S',
#    'sibsp': 3,
#    'parch': 1,
#    'family_size': 5,
#    'is_alone': 0,
#    'title': 'Master'},
#   {'passenger_id': 9,
#    'name': 'Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)',
#    'age': 27.0,
#    'sex': 'female',
#    'survived': 1,
#    'pclass': 3,
#    'fare': 11.1333,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 2,
#    'family_size': 3,
#    'is_alone': 0,
#    'title': 'Mrs'},
#   {'passenger_id': 10,
#    'name': 'Nasser, Mrs. Nicholas (Adele Achem)',
#    'age': 14.0,
#    'sex': 'female',
#    'survived': 1,
#    'pclass': 2,
#    'fare': 30.0708,
#    'embarked': 'C',
#    'sibsp': 1,
#    'parch': 0,
#    'family_size': 2,
#    'is_alone': 0,
#    'title': 'Mrs'},
#   {'passenger_id': 11,
#    'name': 'Sandstrom, Miss. Marguerite Rut',
#    'age': 4.0,
#    'sex': 'female',
#    'survived': 1,
#    'pclass': 3,
#    'fare': 16.7,
#    'embarked': 'S',
#    'sibsp': 1,
#    'parch': 1,
#    'family_size': 3,
#    'is_alone': 0,
#    'title': 'Miss'},
#   {'passenger_id': 12,
#    'name': 'Bonnell, Miss. Elizabeth',
#    'age': 58.0,
#    'sex': 'female',
#    'survived': 1,
#    'pclass': 1,
#    'fare': 26.55,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Miss'},
#   {'passenger_id': 13,
#    'name': 'Saundercock, Mr. William Henry',
#    'age': 20.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 8.05,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 14,
#    'name': 'Andersson, Mr. Anders Johan',
#    'age': 39.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 31.275,
#    'embarked': 'S',
#    'sibsp': 1,
#    'parch': 5,
#    'family_size': 7,
#    'is_alone': 0,
#    'title': 'Mr'},
#   {'passenger_id': 15,
#    'name': 'Vestrom, Miss. Hulda Amanda Adolfina',
#    'age': 14.0,
#    'sex': 'female',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 7.8542,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Miss'},
#   {'passenger_id': 16,
#    'name': 'Hewlett, Mrs. (Mary D Kingcome) ',
#    'age': 55.0,
#    'sex': 'female',
#    'survived': 1,
#    'pclass': 2,
#    'fare': 16.0,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mrs'},
#   {'passenger_id': 17,
#    'name': 'Rice, Master. Eugene',
#    'age': 2.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 29.125,
#    'embarked': 'Q',
#    'sibsp': 4,
#    'parch': 1,
#    'family_size': 6,
#    'is_alone': 0,
#    'title': 'Master'},
#   {'passenger_id': 18,
#    'name': 'Williams, Mr. Charles Eugene',
#    'age': None,
#    'sex': 'male',
#    'survived': 1,
#    'pclass': 2,
#    'fare': 13.0,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 19,
#    'name': 'Vander Planke, Mrs. Julius (Emelia Maria Vandemoortele)',
#    'age': 31.0,
#    'sex': 'female',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 18.0,
#    'embarked': 'S',
#    'sibsp': 1,
#    'parch': 0,
#    'family_size': 2,
#    'is_alone': 0,
#    'title': 'Mrs'},
#   {'passenger_id': 20,
#    'name': 'Masselmani, Mrs. Fatima',
#    'age': None,
#    'sex': 'female',
#    'survived': 1,
#    'pclass': 3,
#    'fare': 7.225,
#    'embarked': 'C',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mrs'},
#   {'passenger_id': 21,
#    'name': 'Fynney, Mr. Joseph J',
#    'age': 35.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 2,
#    'fare': 26.0,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 22,
#    'name': 'Beesley, Mr. Lawrence',
#    'age': 34.0,
#    'sex': 'male',
#    'survived': 1,
#    'pclass': 2,
#    'fare': 13.0,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 23,
#    'name': 'McGowan, Miss. Anna "Annie"',
#    'age': 15.0,
#    'sex': 'female',
#    'survived': 1,
#    'pclass': 3,
#    'fare': 8.0292,
#    'embarked': 'Q',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Miss'},
#   {'passenger_id': 24,
#    'name': 'Sloper, Mr. William Thompson',
#    'age': 28.0,
#    'sex': 'male',
#    'survived': 1,
#    'pclass': 1,
#    'fare': 35.5,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 25,
#    'name': 'Palsson, Miss. Torborg Danira',
#    'age': 8.0,
#    'sex': 'female',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 21.075,
#    'embarked': 'S',
#    'sibsp': 3,
#    'parch': 1,
#    'family_size': 5,
#    'is_alone': 0,
#    'title': 'Miss'},
#   {'passenger_id': 26,
#    'name': 'Asplund, Mrs. Carl Oscar (Selma Augusta Emilia Johansson)',
#    'age': 38.0,
#    'sex': 'female',
#    'survived': 1,
#    'pclass': 3,
#    'fare': 31.3875,
#    'embarked': 'S',
#    'sibsp': 1,
#    'parch': 5,
#    'family_size': 7,
#    'is_alone': 0,
#    'title': 'Mrs'},
#   {'passenger_id': 27,
#    'name': 'Emir, Mr. Farred Chehab',
#    'age': None,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 7.225,
#    'embarked': 'C',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 28,
#    'name': 'Fortune, Mr. Charles Alexander',
#    'age': 19.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 1,
#    'fare': 263.0,
#    'embarked': 'S',
#    'sibsp': 3,
#    'parch': 2,
#    'family_size': 6,
#    'is_alone': 0,
#    'title': 'Mr'},
#   {'passenger_id': 29,
#    'name': 'O\'Dwyer, Miss. Ellen "Nellie"',
#    'age': None,
#    'sex': 'female',
#    'survived': 1,
#    'pclass': 3,
#    'fare': 7.8792,
#    'embarked': 'Q',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Miss'},
#   {'passenger_id': 30,
#    'name': 'Todoroff, Mr. Lalio',
#    'age': None,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 7.8958,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 31,
#    'name': 'Uruchurtu, Don. Manuel E',
#    'age': 40.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 1,
#    'fare': 27.7208,
#    'embarked': 'C',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Don'},
#   {'passenger_id': 32,
#    'name': 'Spencer, Mrs. William Augustus (Marie Eugenie)',
#    'age': None,
#    'sex': 'female',
#    'survived': 1,
#    'pclass': 1,
#    'fare': 146.5208,
#    'embarked': 'C',
#    'sibsp': 1,
#    'parch': 0,
#    'family_size': 2,
#    'is_alone': 0,
#    'title': 'Mrs'},
#   {'passenger_id': 33,
#    'name': 'Glynn, Miss. Mary Agatha',
#    'age': None,
#    'sex': 'female',
#    'survived': 1,
#    'pclass': 3,
#    'fare': 7.75,
#    'embarked': 'Q',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Miss'},
#   {'passenger_id': 34,
#    'name': 'Wheadon, Mr. Edward H',
#    'age': 66.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 2,
#    'fare': 10.5,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 35,
#    'name': 'Meyer, Mr. Edgar Joseph',
#    'age': 28.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 1,
#    'fare': 82.1708,
#    'embarked': 'C',
#    'sibsp': 1,
#    'parch': 0,
#    'family_size': 2,
#    'is_alone': 0,
#    'title': 'Mr'},
#   {'passenger_id': 36,
#    'name': 'Holverson, Mr. Alexander Oskar',
#    'age': 42.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 1,
#    'fare': 52.0,
#    'embarked': 'S',
#    'sibsp': 1,
#    'parch': 0,
#    'family_size': 2,
#    'is_alone': 0,
#    'title': 'Mr'},
#   {'passenger_id': 37,
#    'name': 'Mamee, Mr. Hanna',
#    'age': None,
#    'sex': 'male',
#    'survived': 1,
#    'pclass': 3,
#    'fare': 7.2292,
#    'embarked': 'C',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 38,
#    'name': 'Cann, Mr. Ernest Charles',
#    'age': 21.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 8.05,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 39,
#    'name': 'Vander Planke, Miss. Augusta Maria',
#    'age': 18.0,
#    'sex': 'female',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 18.0,
#    'embarked': 'S',
#    'sibsp': 2,
#    'parch': 0,
#    'family_size': 3,
#    'is_alone': 0,
#    'title': 'Miss'},
#   {'passenger_id': 40,
#    'name': 'Nicola-Yarred, Miss. Jamila',
#    'age': 14.0,
#    'sex': 'female',
#    'survived': 1,
#    'pclass': 3,
#    'fare': 11.2417,
#    'embarked': 'C',
#    'sibsp': 1,
#    'parch': 0,
#    'family_size': 2,
#    'is_alone': 0,
#    'title': 'Miss'},
#   {'passenger_id': 41,
#    'name': 'Ahlin, Mrs. Johan (Johanna Persdotter Larsson)',
#    'age': 40.0,
#    'sex': 'female',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 9.475,
#    'embarked': 'S',
#    'sibsp': 1,
#    'parch': 0,
#    'family_size': 2,
#    'is_alone': 0,
#    'title': 'Mrs'},
#   {'passenger_id': 42,
#    'name': 'Turpin, Mrs. William John Robert (Dorothy Ann Wonnacott)',
#    'age': 27.0,
#    'sex': 'female',
#    'survived': 0,
#    'pclass': 2,
#    'fare': 21.0,
#    'embarked': 'S',
#    'sibsp': 1,
#    'parch': 0,
#    'family_size': 2,
#    'is_alone': 0,
#    'title': 'Mrs'},
#   {'passenger_id': 43,
#    'name': 'Kraeff, Mr. Theodor',
#    'age': None,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 7.8958,
#    'embarked': 'C',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 44,
#    'name': 'Laroche, Miss. Simonne Marie Anne Andree',
#    'age': 3.0,
#    'sex': 'female',
#    'survived': 1,
#    'pclass': 2,
#    'fare': 41.5792,
#    'embarked': 'C',
#    'sibsp': 1,
#    'parch': 2,
#    'family_size': 4,
#    'is_alone': 0,
#    'title': 'Miss'},
#   {'passenger_id': 45,
#    'name': 'Devaney, Miss. Margaret Delia',
#    'age': 19.0,
#    'sex': 'female',
#    'survived': 1,
#    'pclass': 3,
#    'fare': 7.8792,
#    'embarked': 'Q',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Miss'},
#   {'passenger_id': 46,
#    'name': 'Rogers, Mr. William John',
#    'age': None,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 8.05,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 47,
#    'name': 'Lennon, Mr. Denis',
#    'age': None,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 15.5,
#    'embarked': 'Q',
#    'sibsp': 1,
#    'parch': 0,
#    'family_size': 2,
#    'is_alone': 0,
#    'title': 'Mr'},
#   {'passenger_id': 48,
#    'name': "O'Driscoll, Miss. Bridget",
#    'age': None,
#    'sex': 'female',
#    'survived': 1,
#    'pclass': 3,
#    'fare': 7.75,
#    'embarked': 'Q',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Miss'},
#   {'passenger_id': 49,
#    'name': 'Samaan, Mr. Youssef',
#    'age': None,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 21.6792,
#    'embarked': 'C',
#    'sibsp': 2,
#    'parch': 0,
#    'family_size': 3,
#    'is_alone': 0,
#    'title': 'Mr'},
#   {'passenger_id': 50,
#    'name': 'Arnold-Franchi, Mrs. Josef (Josefine Franchi)',
#    'age': 18.0,
#    'sex': 'female',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 17.8,
#    'embarked': 'S',
#    'sibsp': 1,
#    'parch': 0,
#    'family_size': 2,
#    'is_alone': 0,
#    'title': 'Mrs'},
#   {'passenger_id': 51,
#    'name': 'Panula, Master. Juha Niilo',
#    'age': 7.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 39.6875,
#    'embarked': 'S',
#    'sibsp': 4,
#    'parch': 1,
#    'family_size': 6,
#    'is_alone': 0,
#    'title': 'Master'},
#   {'passenger_id': 52,
#    'name': 'Nosworthy, Mr. Richard Cater',
#    'age': 21.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 7.8,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 53,
#    'name': 'Harper, Mrs. Henry Sleeper (Myna Haxtun)',
#    'age': 49.0,
#    'sex': 'female',
#    'survived': 1,
#    'pclass': 1,
#    'fare': 76.7292,
#    'embarked': 'C',
#    'sibsp': 1,
#    'parch': 0,
#    'family_size': 2,
#    'is_alone': 0,
#    'title': 'Mrs'},
#   {'passenger_id': 54,
#    'name': 'Faunthorpe, Mrs. Lizzie (Elizabeth Anne Wilkinson)',
#    'age': 29.0,
#    'sex': 'female',
#    'survived': 1,
#    'pclass': 2,
#    'fare': 26.0,
#    'embarked': 'S',
#    'sibsp': 1,
#    'parch': 0,
#    'family_size': 2,
#    'is_alone': 0,
#    'title': 'Mrs'},
#   {'passenger_id': 55,
#    'name': 'Ostby, Mr. Engelhart Cornelius',
#    'age': 65.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 1,
#    'fare': 61.9792,
#    'embarked': 'C',
#    'sibsp': 0,
#    'parch': 1,
#    'family_size': 2,
#    'is_alone': 0,
#    'title': 'Mr'},
#   {'passenger_id': 56,
#    'name': 'Woolner, Mr. Hugh',
#    'age': None,
#    'sex': 'male',
#    'survived': 1,
#    'pclass': 1,
#    'fare': 35.5,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 57,
#    'name': 'Rugg, Miss. Emily',
#    'age': 21.0,
#    'sex': 'female',
#    'survived': 1,
#    'pclass': 2,
#    'fare': 10.5,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Miss'},
#   {'passenger_id': 58,
#    'name': 'Novel, Mr. Mansouer',
#    'age': 28.5,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 7.2292,
#    'embarked': 'C',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 59,
#    'name': 'West, Miss. Constance Mirium',
#    'age': 5.0,
#    'sex': 'female',
#    'survived': 1,
#    'pclass': 2,
#    'fare': 27.75,
#    'embarked': 'S',
#    'sibsp': 1,
#    'parch': 2,
#    'family_size': 4,
#    'is_alone': 0,
#    'title': 'Miss'},
#   {'passenger_id': 60,
#    'name': 'Goodwin, Master. William Frederick',
#    'age': 11.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 46.9,
#    'embarked': 'S',
#    'sibsp': 5,
#    'parch': 2,
#    'family_size': 8,
#    'is_alone': 0,
#    'title': 'Master'},
#   {'passenger_id': 61,
#    'name': 'Sirayanian, Mr. Orsen',
#    'age': 22.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 7.2292,
#    'embarked': 'C',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 62,
#    'name': 'Icard, Miss. Amelie',
#    'age': 38.0,
#    'sex': 'female',
#    'survived': 1,
#    'pclass': 1,
#    'fare': 80.0,
#    'embarked': None,
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Miss'},
#   {'passenger_id': 63,
#    'name': 'Harris, Mr. Henry Birkhardt',
#    'age': 45.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 1,
#    'fare': 83.475,
#    'embarked': 'S',
#    'sibsp': 1,
#    'parch': 0,
#    'family_size': 2,
#    'is_alone': 0,
#    'title': 'Mr'},
#   {'passenger_id': 64,
#    'name': 'Skoog, Master. Harald',
#    'age': 4.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 27.9,
#    'embarked': 'S',
#    'sibsp': 3,
#    'parch': 2,
#    'family_size': 6,
#    'is_alone': 0,
#    'title': 'Master'},
#   {'passenger_id': 65,
#    'name': 'Stewart, Mr. Albert A',
#    'age': None,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 1,
#    'fare': 27.7208,
#    'embarked': 'C',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 66,
#    'name': 'Moubarek, Master. Gerios',
#    'age': None,
#    'sex': 'male',
#    'survived': 1,
#    'pclass': 3,
#    'fare': 15.2458,
#    'embarked': 'C',
#    'sibsp': 1,
#    'parch': 1,
#    'family_size': 3,
#    'is_alone': 0,
#    'title': 'Master'},
#   {'passenger_id': 67,
#    'name': 'Nye, Mrs. (Elizabeth Ramell)',
#    'age': 29.0,
#    'sex': 'female',
#    'survived': 1,
#    'pclass': 2,
#    'fare': 10.5,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mrs'},
#   {'passenger_id': 68,
#    'name': 'Crease, Mr. Ernest James',
#    'age': 19.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 8.1583,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 69,
#    'name': 'Andersson, Miss. Erna Alexandra',
#    'age': 17.0,
#    'sex': 'female',
#    'survived': 1,
#    'pclass': 3,
#    'fare': 7.925,
#    'embarked': 'S',
#    'sibsp': 4,
#    'parch': 2,
#    'family_size': 7,
#    'is_alone': 0,
#    'title': 'Miss'},
#   {'passenger_id': 70,
#    'name': 'Kink, Mr. Vincenz',
#    'age': 26.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 8.6625,
#    'embarked': 'S',
#    'sibsp': 2,
#    'parch': 0,
#    'family_size': 3,
#    'is_alone': 0,
#    'title': 'Mr'},
#   {'passenger_id': 71,
#    'name': 'Jenkin, Mr. Stephen Curnow',
#    'age': 32.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 2,
#    'fare': 10.5,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 72,
#    'name': 'Goodwin, Miss. Lillian Amy',
#    'age': 16.0,
#    'sex': 'female',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 46.9,
#    'embarked': 'S',
#    'sibsp': 5,
#    'parch': 2,
#    'family_size': 8,
#    'is_alone': 0,
#    'title': 'Miss'},
#   {'passenger_id': 73,
#    'name': 'Hood, Mr. Ambrose Jr',
#    'age': 21.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 2,
#    'fare': 73.5,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 74,
#    'name': 'Chronopoulos, Mr. Apostolos',
#    'age': 26.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 14.4542,
#    'embarked': 'C',
#    'sibsp': 1,
#    'parch': 0,
#    'family_size': 2,
#    'is_alone': 0,
#    'title': 'Mr'},
#   {'passenger_id': 75,
#    'name': 'Bing, Mr. Lee',
#    'age': 32.0,
#    'sex': 'male',
#    'survived': 1,
#    'pclass': 3,
#    'fare': 56.4958,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 76,
#    'name': 'Moen, Mr. Sigurd Hansen',
#    'age': 25.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 7.65,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 77,
#    'name': 'Staneff, Mr. Ivan',
#    'age': None,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 7.8958,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 78,
#    'name': 'Moutal, Mr. Rahamin Haim',
#    'age': None,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 8.05,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 79,
#    'name': 'Caldwell, Master. Alden Gates',
#    'age': 0.83,
#    'sex': 'male',
#    'survived': 1,
#    'pclass': 2,
#    'fare': 29.0,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 2,
#    'family_size': 3,
#    'is_alone': 0,
#    'title': 'Master'},
#   {'passenger_id': 80,
#    'name': 'Dowdell, Miss. Elizabeth',
#    'age': 30.0,
#    'sex': 'female',
#    'survived': 1,
#    'pclass': 3,
#    'fare': 12.475,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Miss'},
#   {'passenger_id': 81,
#    'name': 'Waelens, Mr. Achille',
#    'age': 22.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 9.0,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 82,
#    'name': 'Sheerlinck, Mr. Jan Baptist',
#    'age': 29.0,
#    'sex': 'male',
#    'survived': 1,
#    'pclass': 3,
#    'fare': 9.5,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 83,
#    'name': 'McDermott, Miss. Brigdet Delia',
#    'age': None,
#    'sex': 'female',
#    'survived': 1,
#    'pclass': 3,
#    'fare': 7.7875,
#    'embarked': 'Q',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Miss'},
#   {'passenger_id': 84,
#    'name': 'Carrau, Mr. Francisco M',
#    'age': 28.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 1,
#    'fare': 47.1,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 85,
#    'name': 'Ilett, Miss. Bertha',
#    'age': 17.0,
#    'sex': 'female',
#    'survived': 1,
#    'pclass': 2,
#    'fare': 10.5,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Miss'},
#   {'passenger_id': 86,
#    'name': 'Backstrom, Mrs. Karl Alfred (Maria Mathilda Gustafsson)',
#    'age': 33.0,
#    'sex': 'female',
#    'survived': 1,
#    'pclass': 3,
#    'fare': 15.85,
#    'embarked': 'S',
#    'sibsp': 3,
#    'parch': 0,
#    'family_size': 4,
#    'is_alone': 0,
#    'title': 'Mrs'},
#   {'passenger_id': 87,
#    'name': 'Ford, Mr. William Neal',
#    'age': 16.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 34.375,
#    'embarked': 'S',
#    'sibsp': 1,
#    'parch': 3,
#    'family_size': 5,
#    'is_alone': 0,
#    'title': 'Mr'},
#   {'passenger_id': 88,
#    'name': 'Slocovski, Mr. Selman Francis',
#    'age': None,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 8.05,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 89,
#    'name': 'Fortune, Miss. Mabel Helen',
#    'age': 23.0,
#    'sex': 'female',
#    'survived': 1,
#    'pclass': 1,
#    'fare': 263.0,
#    'embarked': 'S',
#    'sibsp': 3,
#    'parch': 2,
#    'family_size': 6,
#    'is_alone': 0,
#    'title': 'Miss'},
#   {'passenger_id': 90,
#    'name': 'Celotti, Mr. Francesco',
#    'age': 24.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 8.05,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 91,
#    'name': 'Christmann, Mr. Emil',
#    'age': 29.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 8.05,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 92,
#    'name': 'Andreasson, Mr. Paul Edvin',
#    'age': 20.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 7.8542,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 93,
#    'name': 'Chaffee, Mr. Herbert Fuller',
#    'age': 46.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 1,
#    'fare': 61.175,
#    'embarked': 'S',
#    'sibsp': 1,
#    'parch': 0,
#    'family_size': 2,
#    'is_alone': 0,
#    'title': 'Mr'},
#   {'passenger_id': 94,
#    'name': 'Dean, Mr. Bertram Frank',
#    'age': 26.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 20.575,
#    'embarked': 'S',
#    'sibsp': 1,
#    'parch': 2,
#    'family_size': 4,
#    'is_alone': 0,
#    'title': 'Mr'},
#   {'passenger_id': 95,
#    'name': 'Coxon, Mr. Daniel',
#    'age': 59.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 7.25,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 96,
#    'name': 'Shorney, Mr. Charles Joseph',
#    'age': None,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 8.05,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 97,
#    'name': 'Goldschmidt, Mr. George B',
#    'age': 71.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 1,
#    'fare': 34.6542,
#    'embarked': 'C',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 98,
#    'name': 'Greenfield, Mr. William Bertram',
#    'age': 23.0,
#    'sex': 'male',
#    'survived': 1,
#    'pclass': 1,
#    'fare': 63.3583,
#    'embarked': 'C',
#    'sibsp': 0,
#    'parch': 1,
#    'family_size': 2,
#    'is_alone': 0,
#    'title': 'Mr'},
#   {'passenger_id': 99,
#    'name': 'Doling, Mrs. John T (Ada Julia Bone)',
#    'age': 34.0,
#    'sex': 'female',
#    'survived': 1,
#    'pclass': 2,
#    'fare': 23.0,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 1,
#    'family_size': 2,
#    'is_alone': 0,
#    'title': 'Mrs'},
#   {'passenger_id': 100,
#    'name': 'Kantor, Mr. Sinai',
#    'age': 34.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 2,
#    'fare': 26.0,
#    'embarked': 'S',
#    'sibsp': 1,
#    'parch': 0,
#    'family_size': 2,
#    'is_alone': 0,
#    'title': 'Mr'},
#   {'passenger_id': 101,
#    'name': 'Petranec, Miss. Matilda',
#    'age': 28.0,
#    'sex': 'female',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 7.8958,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Miss'},
#   {'passenger_id': 102,
#    'name': 'Petroff, Mr. Pastcho ("Pentcho")',
#    'age': None,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 7.8958,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 103,
#    'name': 'White, Mr. Richard Frasar',
#    'age': 21.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 1,
#    'fare': 77.2875,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 1,
#    'family_size': 2,
#    'is_alone': 0,
#    'title': 'Mr'},
#   {'passenger_id': 104,
#    'name': 'Johansson, Mr. Gustaf Joel',
#    'age': 33.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 8.6542,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 105,
#    'name': 'Gustafsson, Mr. Anders Vilhelm',
#    'age': 37.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 7.925,
#    'embarked': 'S',
#    'sibsp': 2,
#    'parch': 0,
#    'family_size': 3,
#    'is_alone': 0,
#    'title': 'Mr'},
#   {'passenger_id': 106,
#    'name': 'Mionoff, Mr. Stoytcho',
#    'age': 28.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 7.8958,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 107,
#    'name': 'Salkjelsvik, Miss. Anna Kristine',
#    'age': 21.0,
#    'sex': 'female',
#    'survived': 1,
#    'pclass': 3,
#    'fare': 7.65,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Miss'},
#   {'passenger_id': 108,
#    'name': 'Moss, Mr. Albert Johan',
#    'age': None,
#    'sex': 'male',
#    'survived': 1,
#    'pclass': 3,
#    'fare': 7.775,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 109,
#    'name': 'Rekic, Mr. Tido',
#    'age': 38.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 7.8958,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 110,
#    'name': 'Moran, Miss. Bertha',
#    'age': None,
#    'sex': 'female',
#    'survived': 1,
#    'pclass': 3,
#    'fare': 24.15,
#    'embarked': 'Q',
#    'sibsp': 1,
#    'parch': 0,
#    'family_size': 2,
#    'is_alone': 0,
#    'title': 'Miss'},
#   {'passenger_id': 111,
#    'name': 'Porter, Mr. Walter Chamberlain',
#    'age': 47.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 1,
#    'fare': 52.0,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 112,
#    'name': 'Zabour, Miss. Hileni',
#    'age': 14.5,
#    'sex': 'female',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 14.4542,
#    'embarked': 'C',
#    'sibsp': 1,
#    'parch': 0,
#    'family_size': 2,
#    'is_alone': 0,
#    'title': 'Miss'},
#   {'passenger_id': 113,
#    'name': 'Barton, Mr. David John',
#    'age': 22.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 8.05,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 114,
#    'name': 'Jussila, Miss. Katriina',
#    'age': 20.0,
#    'sex': 'female',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 9.825,
#    'embarked': 'S',
#    'sibsp': 1,
#    'parch': 0,
#    'family_size': 2,
#    'is_alone': 0,
#    'title': 'Miss'},
#   {'passenger_id': 115,
#    'name': 'Attalah, Miss. Malake',
#    'age': 17.0,
#    'sex': 'female',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 14.4583,
#    'embarked': 'C',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Miss'},
#   {'passenger_id': 116,
#    'name': 'Pekoniemi, Mr. Edvard',
#    'age': 21.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 7.925,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 117,
#    'name': 'Connors, Mr. Patrick',
#    'age': 70.5,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 7.75,
#    'embarked': 'Q',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 118,
#    'name': 'Turpin, Mr. William John Robert',
#    'age': 29.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 2,
#    'fare': 21.0,
#    'embarked': 'S',
#    'sibsp': 1,
#    'parch': 0,
#    'family_size': 2,
#    'is_alone': 0,
#    'title': 'Mr'},
#   {'passenger_id': 119,
#    'name': 'Baxter, Mr. Quigg Edmond',
#    'age': 24.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 1,
#    'fare': 247.5208,
#    'embarked': 'C',
#    'sibsp': 0,
#    'parch': 1,
#    'family_size': 2,
#    'is_alone': 0,
#    'title': 'Mr'},
#   {'passenger_id': 120,
#    'name': 'Andersson, Miss. Ellis Anna Maria',
#    'age': 2.0,
#    'sex': 'female',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 31.275,
#    'embarked': 'S',
#    'sibsp': 4,
#    'parch': 2,
#    'family_size': 7,
#    'is_alone': 0,
#    'title': 'Miss'},
#   {'passenger_id': 121,
#    'name': 'Hickman, Mr. Stanley George',
#    'age': 21.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 2,
#    'fare': 73.5,
#    'embarked': 'S',
#    'sibsp': 2,
#    'parch': 0,
#    'family_size': 3,
#    'is_alone': 0,
#    'title': 'Mr'},
#   {'passenger_id': 122,
#    'name': 'Moore, Mr. Leonard Charles',
#    'age': None,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 8.05,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 123,
#    'name': 'Nasser, Mr. Nicholas',
#    'age': 32.5,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 2,
#    'fare': 30.0708,
#    'embarked': 'C',
#    'sibsp': 1,
#    'parch': 0,
#    'family_size': 2,
#    'is_alone': 0,
#    'title': 'Mr'},
#   {'passenger_id': 124,
#    'name': 'Webber, Miss. Susan',
#    'age': 32.5,
#    'sex': 'female',
#    'survived': 1,
#    'pclass': 2,
#    'fare': 13.0,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Miss'},
#   {'passenger_id': 125,
#    'name': 'White, Mr. Percival Wayland',
#    'age': 54.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 1,
#    'fare': 77.2875,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 1,
#    'family_size': 2,
#    'is_alone': 0,
#    'title': 'Mr'},
#   {'passenger_id': 126,
#    'name': 'Nicola-Yarred, Master. Elias',
#    'age': 12.0,
#    'sex': 'male',
#    'survived': 1,
#    'pclass': 3,
#    'fare': 11.2417,
#    'embarked': 'C',
#    'sibsp': 1,
#    'parch': 0,
#    'family_size': 2,
#    'is_alone': 0,
#    'title': 'Master'},
#   {'passenger_id': 127,
#    'name': 'McMahon, Mr. Martin',
#    'age': None,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 7.75,
#    'embarked': 'Q',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 128,
#    'name': 'Madsen, Mr. Fridtjof Arne',
#    'age': 24.0,
#    'sex': 'male',
#    'survived': 1,
#    'pclass': 3,
#    'fare': 7.1417,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 129,
#    'name': 'Peter, Miss. Anna',
#    'age': None,
#    'sex': 'female',
#    'survived': 1,
#    'pclass': 3,
#    'fare': 22.3583,
#    'embarked': 'C',
#    'sibsp': 1,
#    'parch': 1,
#    'family_size': 3,
#    'is_alone': 0,
#    'title': 'Miss'},
#   {'passenger_id': 130,
#    'name': 'Ekstrom, Mr. Johan',
#    'age': 45.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 6.975,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 131,
#    'name': 'Drazenoic, Mr. Jozef',
#    'age': 33.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 7.8958,
#    'embarked': 'C',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 132,
#    'name': 'Coelho, Mr. Domingos Fernandeo',
#    'age': 20.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 7.05,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 133,
#    'name': 'Robins, Mrs. Alexander A (Grace Charity Laury)',
#    'age': 47.0,
#    'sex': 'female',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 14.5,
#    'embarked': 'S',
#    'sibsp': 1,
#    'parch': 0,
#    'family_size': 2,
#    'is_alone': 0,
#    'title': 'Mrs'},
#   {'passenger_id': 134,
#    'name': 'Weisz, Mrs. Leopold (Mathilde Francoise Pede)',
#    'age': 29.0,
#    'sex': 'female',
#    'survived': 1,
#    'pclass': 2,
#    'fare': 26.0,
#    'embarked': 'S',
#    'sibsp': 1,
#    'parch': 0,
#    'family_size': 2,
#    'is_alone': 0,
#    'title': 'Mrs'},
#   {'passenger_id': 135,
#    'name': 'Sobey, Mr. Samuel James Hayden',
#    'age': 25.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 2,
#    'fare': 13.0,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 136,
#    'name': 'Richard, Mr. Emile',
#    'age': 23.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 2,
#    'fare': 15.0458,
#    'embarked': 'C',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 137,
#    'name': 'Newsom, Miss. Helen Monypeny',
#    'age': 19.0,
#    'sex': 'female',
#    'survived': 1,
#    'pclass': 1,
#    'fare': 26.2833,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 2,
#    'family_size': 3,
#    'is_alone': 0,
#    'title': 'Miss'},
#   {'passenger_id': 138,
#    'name': 'Futrelle, Mr. Jacques Heath',
#    'age': 37.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 1,
#    'fare': 53.1,
#    'embarked': 'S',
#    'sibsp': 1,
#    'parch': 0,
#    'family_size': 2,
#    'is_alone': 0,
#    'title': 'Mr'},
#   {'passenger_id': 139,
#    'name': 'Osen, Mr. Olaf Elon',
#    'age': 16.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 9.2167,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 140,
#    'name': 'Giglio, Mr. Victor',
#    'age': 24.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 1,
#    'fare': 79.2,
#    'embarked': 'C',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 141,
#    'name': 'Boulos, Mrs. Joseph (Sultana)',
#    'age': None,
#    'sex': 'female',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 15.2458,
#    'embarked': 'C',
#    'sibsp': 0,
#    'parch': 2,
#    'family_size': 3,
#    'is_alone': 0,
#    'title': 'Mrs'},
#   {'passenger_id': 142,
#    'name': 'Nysten, Miss. Anna Sofia',
#    'age': 22.0,
#    'sex': 'female',
#    'survived': 1,
#    'pclass': 3,
#    'fare': 7.75,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Miss'},
#   {'passenger_id': 143,
#    'name': 'Hakkarainen, Mrs. Pekka Pietari (Elin Matilda Dolck)',
#    'age': 24.0,
#    'sex': 'female',
#    'survived': 1,
#    'pclass': 3,
#    'fare': 15.85,
#    'embarked': 'S',
#    'sibsp': 1,
#    'parch': 0,
#    'family_size': 2,
#    'is_alone': 0,
#    'title': 'Mrs'},
#   {'passenger_id': 144,
#    'name': 'Burke, Mr. Jeremiah',
#    'age': 19.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 6.75,
#    'embarked': 'Q',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 145,
#    'name': 'Andrew, Mr. Edgardo Samuel',
#    'age': 18.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 2,
#    'fare': 11.5,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 146,
#    'name': 'Nicholls, Mr. Joseph Charles',
#    'age': 19.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 2,
#    'fare': 36.75,
#    'embarked': 'S',
#    'sibsp': 1,
#    'parch': 1,
#    'family_size': 3,
#    'is_alone': 0,
#    'title': 'Mr'},
#   {'passenger_id': 147,
#    'name': 'Andersson, Mr. August Edvard ("Wennerstrom")',
#    'age': 27.0,
#    'sex': 'male',
#    'survived': 1,
#    'pclass': 3,
#    'fare': 7.7958,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 148,
#    'name': 'Ford, Miss. Robina Maggie "Ruby"',
#    'age': 9.0,
#    'sex': 'female',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 34.375,
#    'embarked': 'S',
#    'sibsp': 2,
#    'parch': 2,
#    'family_size': 5,
#    'is_alone': 0,
#    'title': 'Miss'},
#   {'passenger_id': 149,
#    'name': 'Navratil, Mr. Michel ("Louis M Hoffman")',
#    'age': 36.5,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 2,
#    'fare': 26.0,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 2,
#    'family_size': 3,
#    'is_alone': 0,
#    'title': 'Mr'},
#   {'passenger_id': 150,
#    'name': 'Byles, Rev. Thomas Roussel Davids',
#    'age': 42.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 2,
#    'fare': 13.0,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Rev'},
#   {'passenger_id': 151,
#    'name': 'Bateman, Rev. Robert James',
#    'age': 51.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 2,
#    'fare': 12.525,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Rev'},
#   {'passenger_id': 152,
#    'name': 'Pears, Mrs. Thomas (Edith Wearne)',
#    'age': 22.0,
#    'sex': 'female',
#    'survived': 1,
#    'pclass': 1,
#    'fare': 66.6,
#    'embarked': 'S',
#    'sibsp': 1,
#    'parch': 0,
#    'family_size': 2,
#    'is_alone': 0,
#    'title': 'Mrs'},
#   {'passenger_id': 153,
#    'name': 'Meo, Mr. Alfonzo',
#    'age': 55.5,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 8.05,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 154,
#    'name': 'van Billiard, Mr. Austin Blyler',
#    'age': 40.5,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 14.5,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 2,
#    'family_size': 3,
#    'is_alone': 0,
#    'title': 'Mr'},
#   {'passenger_id': 155,
#    'name': 'Olsen, Mr. Ole Martin',
#    'age': None,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 7.3125,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 156,
#    'name': 'Williams, Mr. Charles Duane',
#    'age': 51.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 1,
#    'fare': 61.3792,
#    'embarked': 'C',
#    'sibsp': 0,
#    'parch': 1,
#    'family_size': 2,
#    'is_alone': 0,
#    'title': 'Mr'},
#   {'passenger_id': 157,
#    'name': 'Gilnagh, Miss. Katherine "Katie"',
#    'age': 16.0,
#    'sex': 'female',
#    'survived': 1,
#    'pclass': 3,
#    'fare': 7.7333,
#    'embarked': 'Q',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Miss'},
#   {'passenger_id': 158,
#    'name': 'Corn, Mr. Harry',
#    'age': 30.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 8.05,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 159,
#    'name': 'Smiljanic, Mr. Mile',
#    'age': None,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 8.6625,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 160,
#    'name': 'Sage, Master. Thomas Henry',
#    'age': None,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 69.55,
#    'embarked': 'S',
#    'sibsp': 8,
#    'parch': 2,
#    'family_size': 11,
#    'is_alone': 0,
#    'title': 'Master'},
#   {'passenger_id': 161,
#    'name': 'Cribb, Mr. John Hatfield',
#    'age': 44.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 16.1,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 1,
#    'family_size': 2,
#    'is_alone': 0,
#    'title': 'Mr'},
#   {'passenger_id': 162,
#    'name': 'Watt, Mrs. James (Elizabeth "Bessie" Inglis Milne)',
#    'age': 40.0,
#    'sex': 'female',
#    'survived': 1,
#    'pclass': 2,
#    'fare': 15.75,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mrs'},
#   {'passenger_id': 163,
#    'name': 'Bengtsson, Mr. John Viktor',
#    'age': 26.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 7.775,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 164,
#    'name': 'Calic, Mr. Jovo',
#    'age': 17.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 8.6625,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 165,
#    'name': 'Panula, Master. Eino Viljami',
#    'age': 1.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 39.6875,
#    'embarked': 'S',
#    'sibsp': 4,
#    'parch': 1,
#    'family_size': 6,
#    'is_alone': 0,
#    'title': 'Master'},
#   {'passenger_id': 166,
#    'name': 'Goldsmith, Master. Frank John William "Frankie"',
#    'age': 9.0,
#    'sex': 'male',
#    'survived': 1,
#    'pclass': 3,
#    'fare': 20.525,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 2,
#    'family_size': 3,
#    'is_alone': 0,
#    'title': 'Master'},
#   {'passenger_id': 167,
#    'name': 'Chibnall, Mrs. (Edith Martha Bowerman)',
#    'age': None,
#    'sex': 'female',
#    'survived': 1,
#    'pclass': 1,
#    'fare': 55.0,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 1,
#    'family_size': 2,
#    'is_alone': 0,
#    'title': 'Mrs'},
#   {'passenger_id': 168,
#    'name': 'Skoog, Mrs. William (Anna Bernhardina Karlsson)',
#    'age': 45.0,
#    'sex': 'female',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 27.9,
#    'embarked': 'S',
#    'sibsp': 1,
#    'parch': 4,
#    'family_size': 6,
#    'is_alone': 0,
#    'title': 'Mrs'},
#   {'passenger_id': 169,
#    'name': 'Baumann, Mr. John D',
#    'age': None,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 1,
#    'fare': 25.925,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 170,
#    'name': 'Ling, Mr. Lee',
#    'age': 28.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 56.4958,
#    'embarked': 'S',
# ...
#   {'passenger_id': 831,
#    'name': 'Yasbeck, Mrs. Antoni (Selini Alexander)',
#    'age': 15.0,
#    'sex': 'female',
#    'survived': 1,
#    'pclass': 3,
#    'fare': 14.4542,
#    'embarked': 'C',
#    'sibsp': 1,
#    'parch': 0,
#    'family_size': 2,
#    'is_alone': 0,
#    'title': 'Mrs'},
#   {'passenger_id': 832,
#    'name': 'Richards, Master. George Sibley',
#    'age': 0.83,
#    'sex': 'male',
#    'survived': 1,
#    'pclass': 2,
#    'fare': 18.75,
#    'embarked': 'S',
#    'sibsp': 1,
#    'parch': 1,
#    'family_size': 3,
#    'is_alone': 0,
#    'title': 'Master'},
#   {'passenger_id': 833,
#    'name': 'Saad, Mr. Amin',
#    'age': None,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 7.2292,
#    'embarked': 'C',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 834,
#    'name': 'Augustsson, Mr. Albert',
#    'age': 23.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 7.8542,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 835,
#    'name': 'Allum, Mr. Owen George',
#    'age': 18.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 8.3,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 836,
#    'name': 'Compton, Miss. Sara Rebecca',
#    'age': 39.0,
#    'sex': 'female',
#    'survived': 1,
#    'pclass': 1,
#    'fare': 83.1583,
#    'embarked': 'C',
#    'sibsp': 1,
#    'parch': 1,
#    'family_size': 3,
#    'is_alone': 0,
#    'title': 'Miss'},
#   {'passenger_id': 837,
#    'name': 'Pasic, Mr. Jakob',
#    'age': 21.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 8.6625,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 838,
#    'name': 'Sirota, Mr. Maurice',
#    'age': None,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 8.05,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 839,
#    'name': 'Chip, Mr. Chang',
#    'age': 32.0,
#    'sex': 'male',
#    'survived': 1,
#    'pclass': 3,
#    'fare': 56.4958,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 840,
#    'name': 'Marechal, Mr. Pierre',
#    'age': None,
#    'sex': 'male',
#    'survived': 1,
#    'pclass': 1,
#    'fare': 29.7,
#    'embarked': 'C',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 841,
#    'name': 'Alhomaki, Mr. Ilmari Rudolf',
#    'age': 20.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 7.925,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 842,
#    'name': 'Mudd, Mr. Thomas Charles',
#    'age': 16.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 2,
#    'fare': 10.5,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 843,
#    'name': 'Serepeca, Miss. Augusta',
#    'age': 30.0,
#    'sex': 'female',
#    'survived': 1,
#    'pclass': 1,
#    'fare': 31.0,
#    'embarked': 'C',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Miss'},
#   {'passenger_id': 844,
#    'name': 'Lemberopolous, Mr. Peter L',
#    'age': 34.5,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 6.4375,
#    'embarked': 'C',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 845,
#    'name': 'Culumovic, Mr. Jeso',
#    'age': 17.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 8.6625,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 846,
#    'name': 'Abbing, Mr. Anthony',
#    'age': 42.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 7.55,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 847,
#    'name': 'Sage, Mr. Douglas Bullen',
#    'age': None,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 69.55,
#    'embarked': 'S',
#    'sibsp': 8,
#    'parch': 2,
#    'family_size': 11,
#    'is_alone': 0,
#    'title': 'Mr'},
#   {'passenger_id': 848,
#    'name': 'Markoff, Mr. Marin',
#    'age': 35.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 7.8958,
#    'embarked': 'C',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 849,
#    'name': 'Harper, Rev. John',
#    'age': 28.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 2,
#    'fare': 33.0,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 1,
#    'family_size': 2,
#    'is_alone': 0,
#    'title': 'Rev'},
#   {'passenger_id': 850,
#    'name': 'Goldenberg, Mrs. Samuel L (Edwiga Grabowska)',
#    'age': None,
#    'sex': 'female',
#    'survived': 1,
#    'pclass': 1,
#    'fare': 89.1042,
#    'embarked': 'C',
#    'sibsp': 1,
#    'parch': 0,
#    'family_size': 2,
#    'is_alone': 0,
#    'title': 'Mrs'},
#   {'passenger_id': 851,
#    'name': 'Andersson, Master. Sigvard Harald Elias',
#    'age': 4.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 31.275,
#    'embarked': 'S',
#    'sibsp': 4,
#    'parch': 2,
#    'family_size': 7,
#    'is_alone': 0,
#    'title': 'Master'},
#   {'passenger_id': 852,
#    'name': 'Svensson, Mr. Johan',
#    'age': 74.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 7.775,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 853,
#    'name': 'Boulos, Miss. Nourelain',
#    'age': 9.0,
#    'sex': 'female',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 15.2458,
#    'embarked': 'C',
#    'sibsp': 1,
#    'parch': 1,
#    'family_size': 3,
#    'is_alone': 0,
#    'title': 'Miss'},
#   {'passenger_id': 854,
#    'name': 'Lines, Miss. Mary Conover',
#    'age': 16.0,
#    'sex': 'female',
#    'survived': 1,
#    'pclass': 1,
#    'fare': 39.4,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 1,
#    'family_size': 2,
#    'is_alone': 0,
#    'title': 'Miss'},
#   {'passenger_id': 855,
#    'name': 'Carter, Mrs. Ernest Courtenay (Lilian Hughes)',
#    'age': 44.0,
#    'sex': 'female',
#    'survived': 0,
#    'pclass': 2,
#    'fare': 26.0,
#    'embarked': 'S',
#    'sibsp': 1,
#    'parch': 0,
#    'family_size': 2,
#    'is_alone': 0,
#    'title': 'Mrs'},
#   {'passenger_id': 856,
#    'name': 'Aks, Mrs. Sam (Leah Rosen)',
#    'age': 18.0,
#    'sex': 'female',
#    'survived': 1,
#    'pclass': 3,
#    'fare': 9.35,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 1,
#    'family_size': 2,
#    'is_alone': 0,
#    'title': 'Mrs'},
#   {'passenger_id': 857,
#    'name': 'Wick, Mrs. George Dennick (Mary Hitchcock)',
#    'age': 45.0,
#    'sex': 'female',
#    'survived': 1,
#    'pclass': 1,
#    'fare': 164.8667,
#    'embarked': 'S',
#    'sibsp': 1,
#    'parch': 1,
#    'family_size': 3,
#    'is_alone': 0,
#    'title': 'Mrs'},
#   {'passenger_id': 858,
#    'name': 'Daly, Mr. Peter Denis ',
#    'age': 51.0,
#    'sex': 'male',
#    'survived': 1,
#    'pclass': 1,
#    'fare': 26.55,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 859,
#    'name': 'Baclini, Mrs. Solomon (Latifa Qurban)',
#    'age': 24.0,
#    'sex': 'female',
#    'survived': 1,
#    'pclass': 3,
#    'fare': 19.2583,
#    'embarked': 'C',
#    'sibsp': 0,
#    'parch': 3,
#    'family_size': 4,
#    'is_alone': 0,
#    'title': 'Mrs'},
#   {'passenger_id': 860,
#    'name': 'Razi, Mr. Raihed',
#    'age': None,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 7.2292,
#    'embarked': 'C',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 861,
#    'name': 'Hansen, Mr. Claus Peter',
#    'age': 41.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 14.1083,
#    'embarked': 'S',
#    'sibsp': 2,
#    'parch': 0,
#    'family_size': 3,
#    'is_alone': 0,
#    'title': 'Mr'},
#   {'passenger_id': 862,
#    'name': 'Giles, Mr. Frederick Edward',
#    'age': 21.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 2,
#    'fare': 11.5,
#    'embarked': 'S',
#    'sibsp': 1,
#    'parch': 0,
#    'family_size': 2,
#    'is_alone': 0,
#    'title': 'Mr'},
#   {'passenger_id': 863,
#    'name': 'Swift, Mrs. Frederick Joel (Margaret Welles Barron)',
#    'age': 48.0,
#    'sex': 'female',
#    'survived': 1,
#    'pclass': 1,
#    'fare': 25.9292,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mrs'},
#   {'passenger_id': 864,
#    'name': 'Sage, Miss. Dorothy Edith "Dolly"',
#    'age': None,
#    'sex': 'female',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 69.55,
#    'embarked': 'S',
#    'sibsp': 8,
#    'parch': 2,
#    'family_size': 11,
#    'is_alone': 0,
#    'title': 'Miss'},
#   {'passenger_id': 865,
#    'name': 'Gill, Mr. John William',
#    'age': 24.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 2,
#    'fare': 13.0,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 866,
#    'name': 'Bystrom, Mrs. (Karolina)',
#    'age': 42.0,
#    'sex': 'female',
#    'survived': 1,
#    'pclass': 2,
#    'fare': 13.0,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mrs'},
#   {'passenger_id': 867,
#    'name': 'Duran y More, Miss. Asuncion',
#    'age': 27.0,
#    'sex': 'female',
#    'survived': 1,
#    'pclass': 2,
#    'fare': 13.8583,
#    'embarked': 'C',
#    'sibsp': 1,
#    'parch': 0,
#    'family_size': 2,
#    'is_alone': 0,
#    'title': 'Miss'},
#   {'passenger_id': 868,
#    'name': 'Roebling, Mr. Washington Augustus II',
#    'age': 31.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 1,
#    'fare': 50.4958,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 869,
#    'name': 'van Melkebeke, Mr. Philemon',
#    'age': None,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 9.5,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 870,
#    'name': 'Johnson, Master. Harold Theodor',
#    'age': 4.0,
#    'sex': 'male',
#    'survived': 1,
#    'pclass': 3,
#    'fare': 11.1333,
#    'embarked': 'S',
#    'sibsp': 1,
#    'parch': 1,
#    'family_size': 3,
#    'is_alone': 0,
#    'title': 'Master'},
#   {'passenger_id': 871,
#    'name': 'Balkic, Mr. Cerin',
#    'age': 26.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 7.8958,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 872,
#    'name': 'Beckwith, Mrs. Richard Leonard (Sallie Monypeny)',
#    'age': 47.0,
#    'sex': 'female',
#    'survived': 1,
#    'pclass': 1,
#    'fare': 52.5542,
#    'embarked': 'S',
#    'sibsp': 1,
#    'parch': 1,
#    'family_size': 3,
#    'is_alone': 0,
#    'title': 'Mrs'},
#   {'passenger_id': 873,
#    'name': 'Carlsson, Mr. Frans Olof',
#    'age': 33.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 1,
#    'fare': 5.0,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 874,
#    'name': 'Vander Cruyssen, Mr. Victor',
#    'age': 47.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 9.0,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 875,
#    'name': 'Abelson, Mrs. Samuel (Hannah Wizosky)',
#    'age': 28.0,
#    'sex': 'female',
#    'survived': 1,
#    'pclass': 2,
#    'fare': 24.0,
#    'embarked': 'C',
#    'sibsp': 1,
#    'parch': 0,
#    'family_size': 2,
#    'is_alone': 0,
#    'title': 'Mrs'},
#   {'passenger_id': 876,
#    'name': 'Najib, Miss. Adele Kiamie "Jane"',
#    'age': 15.0,
#    'sex': 'female',
#    'survived': 1,
#    'pclass': 3,
#    'fare': 7.225,
#    'embarked': 'C',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Miss'},
#   {'passenger_id': 877,
#    'name': 'Gustafsson, Mr. Alfred Ossian',
#    'age': 20.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 9.8458,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 878,
#    'name': 'Petroff, Mr. Nedelio',
#    'age': 19.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 7.8958,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 879,
#    'name': 'Laleff, Mr. Kristo',
#    'age': None,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 7.8958,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 880,
#    'name': 'Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)',
#    'age': 56.0,
#    'sex': 'female',
#    'survived': 1,
#    'pclass': 1,
#    'fare': 83.1583,
#    'embarked': 'C',
#    'sibsp': 0,
#    'parch': 1,
#    'family_size': 2,
#    'is_alone': 0,
#    'title': 'Mrs'},
#   {'passenger_id': 881,
#    'name': 'Shelley, Mrs. William (Imanita Parrish Hall)',
#    'age': 25.0,
#    'sex': 'female',
#    'survived': 1,
#    'pclass': 2,
#    'fare': 26.0,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 1,
#    'family_size': 2,
#    'is_alone': 0,
#    'title': 'Mrs'},
#   {'passenger_id': 882,
#    'name': 'Markun, Mr. Johann',
#    'age': 33.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 7.8958,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 883,
#    'name': 'Dahlberg, Miss. Gerda Ulrika',
#    'age': 22.0,
#    'sex': 'female',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 10.5167,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Miss'},
#   {'passenger_id': 884,
#    'name': 'Banfield, Mr. Frederick James',
#    'age': 28.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 2,
#    'fare': 10.5,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 885,
#    'name': 'Sutehall, Mr. Henry Jr',
#    'age': 25.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 7.05,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 886,
#    'name': 'Rice, Mrs. William (Margaret Norton)',
#    'age': 39.0,
#    'sex': 'female',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 29.125,
#    'embarked': 'Q',
#    'sibsp': 0,
#    'parch': 5,
#    'family_size': 6,
#    'is_alone': 0,
#    'title': 'Mrs'},
#   {'passenger_id': 887,
#    'name': 'Montvila, Rev. Juozas',
#    'age': 27.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 2,
#    'fare': 13.0,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Rev'},
#   {'passenger_id': 888,
#    'name': 'Graham, Miss. Margaret Edith',
#    'age': 19.0,
#    'sex': 'female',
#    'survived': 1,
#    'pclass': 1,
#    'fare': 30.0,
#    'embarked': 'S',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Miss'},
#   {'passenger_id': 889,
#    'name': 'Johnston, Miss. Catherine Helen "Carrie"',
#    'age': None,
#    'sex': 'female',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 23.45,
#    'embarked': 'S',
#    'sibsp': 1,
#    'parch': 2,
#    'family_size': 4,
#    'is_alone': 0,
#    'title': 'Miss'},
#   {'passenger_id': 890,
#    'name': 'Behr, Mr. Karl Howell',
#    'age': 26.0,
#    'sex': 'male',
#    'survived': 1,
#    'pclass': 1,
#    'fare': 30.0,
#    'embarked': 'C',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'},
#   {'passenger_id': 891,
#    'name': 'Dooley, Mr. Patrick',
#    'age': 32.0,
#    'sex': 'male',
#    'survived': 0,
#    'pclass': 3,
#    'fare': 7.75,
#    'embarked': 'Q',
#    'sibsp': 0,
#    'parch': 0,
#    'family_size': 1,
#    'is_alone': 1,
#    'title': 'Mr'}]}

# %%
# Additional validation: Load and inspect JSON
with open(JSON_FILE, 'r', encoding='utf-8') as f:
    json_data = json.load(f)

# Print summary of JSON data and verify content
print("\n" + "=" * 50)
print("JSON DATA INSPECTION")
print("=" * 50)
print("Metadata:")
for k, v in json_data.get("metadata", {}).items():
    print(f"  {k}: {v}")
# Out:
# ==================================================
# JSON DATA INSPECTION
# ==================================================
# Metadata:
#   dataset_name: Titanic Passenger Dataset
#   export_date: 2026-02-03T18:09:39.010376
#   rows: 891
#   columns: 15
#   column_names: ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'FamilySize', 'IsAlone', 'Title']
#   summary_stats: {'total_passengers': 891, 'survived': 342, 'did_not_survive': 549, 'survival_rate': 0.3838383838383838, 'average_age': 29.699, 'average_fare': 32.204, 'average_family_size': 1.905}
#   missing_values: {'PassengerId': {'missing_count': 0, 'missing_percent': 0.0}, 'Survived': {'missing_count': 0, 'missing_percent': 0.0}, 'Pclass': {'missing_count': 0, 'missing_percent': 0.0}, 'Name': {'missing_count': 0, 'missing_percent': 0.0}, 'Sex': {'missing_count': 0, 'missing_percent': 0.0}, 'Age': {'missing_count': 177, 'missing_percent': 19.87}, 'SibSp': {'missing_count': 0, 'missing_percent': 0.0}, 'Parch': {'missing_count': 0, 'missing_percent': 0.0}, 'Ticket': {'missing_count': 0, 'missing_percent': 0.0}, 'Fare': {'missing_count': 0, 'missing_percent': 0.0}, 'Cabin': {'missing_count': 687, 'missing_percent': 77.1}, 'Embarked': {'missing_count': 2, 'missing_percent': 0.22}, 'FamilySize': {'missing_count': 0, 'missing_percent': 0.0}, 'IsAlone': {'missing_count': 0, 'missing_percent': 0.0}, 'Title': {'missing_count': 0, 'missing_percent': 0.0}}
#   top_missing_columns: [{'column': 'Cabin', 'missing_count': 687, 'missing_percent': 77.1}, {'column': 'Age', 'missing_count': 177, 'missing_percent': 19.87}, {'column': 'Embarked', 'missing_count': 2, 'missing_percent': 0.22}, {'column': 'PassengerId', 'missing_count': 0, 'missing_percent': 0.0}, {'column': 'Survived', 'missing_count': 0, 'missing_percent': 0.0}, {'column': 'Pclass', 'missing_count': 0, 'missing_percent': 0.0}, {'column': 'Name', 'missing_count': 0, 'missing_percent': 0.0}, {'column': 'Sex', 'missing_count': 0, 'missing_percent': 0.0}, {'column': 'SibSp', 'missing_count': 0, 'missing_percent': 0.0}, {'column': 'Parch', 'missing_count': 0, 'missing_percent': 0.0}]
#   numeric_column_stats: {'PassengerId': {'mean': 446.0, 'median': 446.0, 'std': 257.354}, 'Survived': {'mean': 0.384, 'median': 0.0, 'std': 0.487}, 'Pclass': {'mean': 2.309, 'median': 3.0, 'std': 0.836}, 'Age': {'mean': 29.699, 'median': 28.0, 'std': 14.526}, 'SibSp': {'mean': 0.523, 'median': 0.0, 'std': 1.103}, 'Parch': {'mean': 0.382, 'median': 0.0, 'std': 0.806}, 'Fare': {'mean': 32.204, 'median': 14.454, 'std': 49.693}, 'FamilySize': {'mean': 1.905, 'median': 1.0, 'std': 1.613}, 'IsAlone': {'mean': 0.603, 'median': 1.0, 'std': 0.49}}
#   engineered_features: {'FamilySize': 'SibSp + Parch + 1', 'IsAlone': '1 if FamilySize == 1 else 0', 'Title': "Extracted from Name (text between ',' and '.')"}
